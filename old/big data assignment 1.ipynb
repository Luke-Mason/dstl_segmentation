# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
text_file = open("/home/kaien125/big data processing/assignment 1/task3_output/task3_output", "r")
lines = text_file.readlines()
print(lines)
print(len(lines))
text_file.close()

# %%
task3_output = []
for line in lines:
    line = line.replace('\t', ' ')
    task3_output.append(line)
    
print(task3_output)
print(len(task3_output))
# Out:
# ['"Canvas 1\n', '"Come 2\n', '"European 1\n', '"I 3\n', '"I\'ll 1\n', '"It\'s 1\n', '"Marvellous 1\n', '"Melburnians".[note 1\n', '"Paris 1\n', '"RMIT 3\n', '"That\'s 1\n', '"a 2\n', '"bay 1\n', '"evidence 1\n', '"green 1\n', '"grey 1\n', '"just 1\n', '"land 2\n', '"no". 1\n', '"one 1\n', '$3.1 1\n', '& 4\n', "'white 1\n", '(0.9%).[191] 1\n', '(1,691 1\n', '(1.57) 1\n', '(1.6%), 1\n', '(1.60) 1\n', '(1.78) 1\n', '(1.8%) 1\n', '(1.8%).[186] 1\n', '(1.99) 1\n', '(114.1) 1\n', '(115.5 1\n', '(1883) 1\n', '(1889) 1\n', '(1986), 1\n', '(2.08) 1\n', '(2.4%) 1\n', '(2008). 1\n', '(2011-2017).[21] 1\n', '(2016)[182] 1\n', '(27.0 1\n', '(28%) 1\n', '(28.0) 1\n', '(289 1\n', '(2nd) 1\n', '(3.9%) 1\n', '(32.2) 1\n', '(37.0) 2\n', '(4.3%), 1\n', '(406 1\n', '(41.5) 1\n', '(43.3) 1\n', '(44.8) 1\n', '(46.0) 1\n', '(46.9) 1\n', '(49 1\n', '(49.3) 1\n', '(49.6) 1\n', '(51.1) 1\n', '(53.1 1\n', '(53.2) 2\n', '(54.7) 1\n', '(57.4) 1\n', '(58.6) 1\n', '(6,147/sq 1\n', '(60.1) 1\n', '(63.7) 2\n', '(66.
# ...

# %%
# task3_output = []
# with open('/home/kaien125/big data processing/assignment 1/task3_output/task3_output', 'r') as fd:
#     reader = csv.reader(fd)
#     for row in reader:
#         task3_output.append(row)
# print(task3_output)

# %%
outputTest = open("/home/kaien125/big data processing/assignment1/outputTest.txt", "r")
outputTest_lines = outputTest.readlines()
print(outputTest_lines)
print(len(outputTest_lines))
outputTest.close()
# Out:
# ['seaport 1\n', 'reuse 1\n', 'roared, 1\n', "don't 1\n", 'Library, 1\n', 'kilometre,[113] 1\n', 'hall 4\n', 'pollution 2\n', '(48.6) 1\n', 'Western 3\n', 'would 2\n', 'culturally 1\n', 'City" 1\n', 'legs 1\n', '79,054 1\n', 'oceanic 1\n', 'Montage 1\n', 'mind: 1\n', 'ten 2\n', 'Building. 2\n', 'Building, 8\n', 'solid 3\n', 'notably 7\n', '& 4\n', 'attendees 1\n', 'investment 2\n', 'Sorrento. 1\n', 'low-density 2\n', '. 3\n', '(61.5) 1\n', 'completion, 1\n', 'Building) 3\n', '10.6 1\n', '1 16\n', '10.5 1\n', '2 7\n', '3 6\n', '4 7\n', 'size 1\n', '10.2 1\n', 'left 5\n', '5 7\n', 'reserved 1\n', '6 3\n', '10.0 1\n', '7 5\n', 'Hotel, 1\n', '8 5\n', '9 9\n', 'Stars, 1\n', 'Melbourne.[73] 1\n', 'goin 1\n', 'seaport, 1\n', 'SEN 1\n', '10.7 1\n', '@ 1\n', 'newspaper 1\n', 'A 14\n', 'statistical 2\n', '(73.0) 1\n', 'role 4\n', '(ATV), 1\n', 'E 2\n', 'hosting 1\n', '1000 2\n', 'I 7\n', 'notable 2\n', 'J 1\n', 'turn 1\n', '9Gem 1\n', 'example 2\n', 'gold 12\n', 'result 3\n', 'golf 1\n', 'same 
# ...

# %%
list_difference = []
for item in task3_output:
  if item not in outputTest_lines:
    list_difference.append(item)

print(list_difference)
# Out:
# ['(K�ppen 1\n', '(�F) 7\n', '2013�2014 1\n', '2013�2014, 2\n', "37�48'49?S 2\n", 'A�16,000,[36] 1\n', 'A�25,000 1\n', 'Diemen�s 1\n', 'Ni�o 1\n', 'River�to 1\n', '�C 15\n', '�F 2\n', '�F).[77] 1\n', '(1981�2010) 1\n', "144�57'47?ECoordinates: 1\n", 'Bay�the 1\n', 'North�South 1\n', 'University�s 2\n', 'caf� 2\n', 'cathedrals�St 1\n', 'city�almost 1\n', 'stale�the 1\n', 'tributaries�Moonee 1\n', '�10,600.[22] 1\n', '�25,000 1\n', '�5,000 1\n', '�F), 2\n', "144�57'47?E 1\n", '1930�31, 1\n', '76th�100th 1\n', 'A�40,000,[40] 1\n', 'Wathaurong�inhabited 1\n', 'd�cor.[61] 1\n', 'festival�Moomba, 1\n', 'tribes�the 1\n', 'workers�something 1\n', '� 32\n', '�13,700.[22] 1\n', '�F) 3\n']

# %%
list_difference = []
for item in outputTest_lines:
  if item not in task3_output:
    list_difference.append(item)

print(list_difference)
print(len(list_difference))
# Out:
# ['°F).[77] 1\n', '\x95 2\n', '\x96 24\n', '\x97 2\n', '· 4\n', 'A£25,000 1\n', 'décor.[61] 1\n', 'University\x92s 2\n', 'Wathaurong\x97inhabited 1\n', 'River\x97to 1\n', 'stale\x97the 1\n', "144°57'47?ECoordinates: 1\n", '£25,000 1\n', 'festival\x97Moomba, 1\n', "144°57'47?E 1\n", '£13,700.[22] 1\n', '(°F) 7\n', "37°48'49?S 2\n", '°F), 2\n', '(1981\x962010) 1\n', '£10,600.[22] 1\n', '1930\x9631, 1\n', '2013\x962014, 2\n', '76th\x96100th 1\n', 'cathedrals\x97St 1\n', 'Bay\x97the 1\n', '°C 15\n', '°F 2\n', 'tribes\x97the 1\n', 'Diemen\x92s 1\n', 'A£40,000,[40] 1\n', 'workers\x97something 1\n', 'tributaries\x97Moonee 1\n', '(Köppen 1\n', 'café 2\n', 'North\x96South 1\n', 'city\x97almost 1\n', '£5,000 1\n', 'Niño 1\n', '°F) 3\n', 'A£16,000,[36] 1\n', '2013\x962014 1\n']
# 42

# %%
results = pd.read_csv (r'/home/kaien125/big data processing/assignment 1/readme.txt')

# %%
results
# Out:
#      task          input  MAP_OUTPUT_RECORDS  MAP_OUTPUT_BYTES  \
# 0   task0   melbourne*10              116640           1703200
# 1   task2   melbourne*10               89410           1354020
# 2   task3   melbourne*10               42210            681500
# 3   task0  littlepigs*72               72360            959544
# 4   task2  littlepigs*72               68616            915480
# 5   task3  littlepigs*72               35784            509112
# 6   task0         3doc*7              119462           1726529
# 7   task2         3doc*7               92491           1383459
# 8   task3         3doc*7               43442            696717
# 9   task0        RMIT*32              140704           2016000
# 10  task2        RMIT*32              106208           1584640
# 11  task3        RMIT*32               47616            777920
#
#     CPU_MILLISECONDS  MAP_INPUT_RECORDS  REDUCE_INPUT_GROUPS
# 0              11070               5990                 4221
# ...

# %%
token_per_line = pd.read_csv (r'/home/kaien125/big data processing/assignment 1/token_per_line.txt')

# %%
token_per_line
# Out:
#         input  token_per_line
# 0  littlepigs             5.9
# 1   melbourne             7.0
# 2       3 doc             6.4
# 3        RMIT             8.0
